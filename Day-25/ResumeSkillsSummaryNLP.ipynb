# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn. metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('/content/sample_data/UpdatedResumeDataSet.csv',encoding='utf-8')
print('Shape of Data Frame',df.shape)
df.head()
# Out:
# Shape of Data Frame (962, 2)
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
print('\n Columns',df.columns.tolist())
# Out:
#  Columns ['Category', 'Resume']

# %%
sample_df=df.sample(10,random_state=42).reset_index(drop=True)
sample_df
# Out:
#                     Category  \
# 0             Java Developer
# 1             Java Developer
# 2             Java Developer
# 3                     Hadoop
# 4         Health and fitness
# 5  Network Security Engineer
# 6        Mechanical Engineer
# 7         Automation Testing
# 8                   Advocate
# 9         Health and fitness
#
#                                               Resume
# 0  TECHNICAL SKILLS Programming Languages: Java (...
# 1  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 2  Education Details \r\nJanuary 2013 Master of E...
# 3  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 4  Education Details \r\nJanuary 1992 to January ...
# 5  Technical Expertise: â¢ Cisco ASA, Checkpoint...
# 6  Education Details \r\nMay 1999 to September 20...
# 7  Technical Skills Summary I have completed "COR...
# 8  Education Details \r\n LLB.   Dibrugarh Univer...
# 9  SKILLS: Computer: â¢ Can easily operate in Op...

# %%
sample_df = sample_df.rename(columns={'Resume':'Resume_Text'})
sample_df
# Out:
#                     Category  \
# 0             Java Developer
# 1             Java Developer
# 2             Java Developer
# 3                     Hadoop
# 4         Health and fitness
# 5  Network Security Engineer
# 6        Mechanical Engineer
# 7         Automation Testing
# 8                   Advocate
# 9         Health and fitness
#
#                                          Resume_Text
# 0  TECHNICAL SKILLS Programming Languages: Java (...
# 1  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 2  Education Details \r\nJanuary 2013 Master of E...
# 3  Skill Set: Hadoop, Map Reduce, HDFS, Hive, Sqo...
# 4  Education Details \r\nJanuary 1992 to January ...
# 5  Technical Expertise: â¢ Cisco ASA, Checkpoint...
# 6  Education Details \r\nMay 1999 to September 20...
# 7  Technical Skills Summary I have completed "COR...
# 8  Education Details \r\n LLB.   Dibrugarh Univer...
# 9  SKILLS: Computer: â¢ Can easily operate in Op...

# %%
# Step 1: Initialize the TF-IDF vectorizer
# stop_words='english' removes common English words like 'the', 'is', 'and'
vectorizer = TfidfVectorizer(stop_words='english')

# Step 2: Fit the vectorizer on the 'Resume_Text' column
# and transform the text into a TF-IDF matrix
# Each resume will be converted into a vector of TF-IDF features
tfidf_matrix = vectorizer.fit_transform(sample_df['Resume_Text'])

# Step 3: Check the shape of the TF-IDF matrix
# The output is (number_of_documents, number_of_features)
tfidf_matrix.shape
# Out:
# (10, 1125)

# %%
# Compute cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix)

# Convert to DataFrame with proper index and columns
sim_df = pd.DataFrame(
    similarity_matrix,
    index=sample_df["Category"] + "_" + sample_df.index.astype(str),
    columns=sample_df["Category"] + "_" + sample_df.index.astype(str)
)

sim_df.round(2).head()
# Out:
#                       Java Developer_0  Java Developer_1  Java Developer_2  \
# Java Developer_0                  1.00              0.41              0.24
# Java Developer_1                  0.41              1.00              0.22
# Java Developer_2                  0.24              0.22              1.00
# Hadoop_3                          0.11              0.14              0.11
# Health and fitness_4              0.06              0.03              0.07
#
#                       Hadoop_3  Health and fitness_4  \
# Java Developer_0          0.11                  0.06
# Java Developer_1          0.14                  0.03
# Java Developer_2          0.11                  0.07
# Hadoop_3                  1.00                  0.02
# Health and fitness_4      0.02                  1.00
#
#                       Network Security Engineer_5  Mechanical Engineer_6  \
# Java Developer_0                             0.07                   0.06
# ...

# %% [markdown]
# ## Resume Screening Example 2

# %%
resumes={
    "candidate":['Sam','Arsh','Maan'],
    "resume_text":["Python developer skilled in Django,Flask, Rest API and MySQL",
                   "Machine learning engineer experience in Python,TensorFlow, NLP and data analysis",
                   "Full stack developer with .net, javascript,React, Node.js and MongoDB experience" ]
}

# %%
df=pd.DataFrame(resumes)
df
# Out:
#   candidate                                        resume_text
# 0       Sam  Python developer skilled in Django,Flask, Rest...
# 1      Arsh  Machine learning engineer experience in Python...
# 2      Maan  Full stack developer with .net, javascript,Rea...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Step 1: Initialize TF-IDF Vectorizer
# stop_words='english' ignores common English words
vectorizer = TfidfVectorizer(stop_words='english')

# Step 2: Fit the vectorizer and transform the 'resume_text' column
# Each document (resume) is converted into a TF-IDF vector
tfidf_matrix = vectorizer.fit_transform(df['resume_text'])

# Step 3: Check the shape of the TF-IDF matrix
# Output: (number_of_documents, number_of_features)
print(tfidf_matrix.shape)

# Step 4: View the TF-IDF matrix
tfidf_matrix
# Out:
# (3, 23)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 26 stored elements and shape (3, 23)>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Step 1: Compute cosine similarity between all resumes
similarity_matrix = cosine_similarity(tfidf_matrix)

# Step 2: Convert the similarity matrix into a pandas DataFrame
# Use 'candidate' column for row and column labels
sim_df = pd.DataFrame(
    similarity_matrix,
    index=df["candidate"],
    columns=df["candidate"]
)

# Step 3: Round the values to 2 decimal places for readability
sim_df = sim_df.round(2)

# Display the similarity DataFrame
sim_df
# Out:
# candidate   Sam  Arsh  Maan
# candidate
# Sam        1.00  0.08  0.08
# Arsh       0.08  1.00  0.07
# Maan       0.08  0.07  1.00

# %%
# Add a new row to the DataFrame
df.loc[len(df)] = ["Zoya", "Backend developer skilled in Python, Flask and SQL"]

# Display updated DataFrame
df
# Out:
#   candidate                                        resume_text
# 0       Sam  Python developer skilled in Django,Flask, Rest...
# 1      Arsh  Machine learning engineer experience in Python...
# 2      Maan  Full stack developer with .net, javascript,Rea...
# 3      Zoya  Backend developer skilled in Python, Flask and...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Step 1: Initialize the TF-IDF vectorizer
# stop_words='english' ignores common English words like 'the', 'is', 'and'
vectorizer = TfidfVectorizer(stop_words='english')

# Step 2: Fit the vectorizer on the 'resume_text' column
# and transform the text into a TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(df['resume_text'])

# Step 3: Check the shape of the TF-IDF matrix
# Output: (number_of_documents, number_of_features)
print(tfidf_matrix.shape)

# Step 4: View the TF-IDF matrix
tfidf_matrix
# Out:
# (4, 25)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 32 stored elements and shape (4, 25)>

# %%
similarity_matrix = cosine_similarity(tfidf_matrix)
sim_df = pd.DataFrame(
    similarity_matrix,
    index=df["candidate"],
    columns=df["candidate"]
)
sim_df = sim_df.round(2)
sim_df
# Out:
# candidate   Sam  Arsh  Maan  Zoya
# candidate
# Sam        1.00  0.06  0.06  0.42
# Arsh       0.06  1.00  0.08  0.07
# Maan       0.06  0.08  1.00  0.07
# Zoya       0.42  0.07  0.07  1.00
