# %%
# !pip install -U Spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 37.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")

text = "Apple is opening a new office in Paris in 2025."

# Process the text
doc = nlp(text)

# Print entities
for ent in doc.ents:
    print(ent.text, ent.label_)

# In short: NER finds the “who, what, where, when” in your text and labels them.
# Out:
# Apple ORG
# Paris GPE
# 2025 DATE

# %%
text="IIUM professor doubles down: 'Romans learned shipbuilding from Malays' theory based on extensive study"

# %%
doc = nlp(text)
for ent in doc.ents:
    print(f'Text: {ent.text},Label: {ent.label_},Explanation: {spacy.explain(ent.label_)}\n')
# Out:
# Text: IIUM,Label: ORG,Explanation: Companies, agencies, institutions, etc.
#
# Text: Romans,Label: NORP,Explanation: Nationalities or religious or political groups
#
# Text: Malays,Label: ORG,Explanation: Companies, agencies, institutions, etc.

# %%
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IIUM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  professor doubles down: '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Romans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  learned shipbuilding from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malays
# ...

# %%
corpus = [
    "Barack Obama visited Kuala Lumpur on 10th November 2025 to attend the UN conference.",
    "Apple Inc. announced the release of the new iPhone 15, priced at $999, at their headquarters in Cupertino.",
    "The Eiffel Tower is one of the most famous landmarks in Paris.",
    "Python and Java are popular programming languages used in AI and data science projects.",
    "The company achieved a 25% increase in revenue this quarter.",
    "The World Cup 2026 will be held in multiple cities across the USA, Canada, and Mexico.",
    "The Malaysian Parliament passed the new Data Protection Act yesterday.",
    "Tesla's new Model S Plaid can reach 0-60 mph in less than 2 seconds.",
    "The Olympics opening ceremony will start at 8:00 PM local time.",
    "Harvard University and MIT are renowned educational institutions in the USA."
]

# %%
# Named Entity Recognition (NER) on a corpus
for text in corpus:
    # Process each document with spaCy NLP pipeline
    doc = nlp(text)

    # Display the original text
    print(f'\nText: {text}')

    # Loop through detected named entities and display them
    for ent in doc.ents:
        print(f'{ent.text} -> {ent.label_}')
# Out:
# Text: Barack Obama visited Kuala Lumpur on 10th November 2025 to attend the UN conference.
# Barack Obama -> PERSON
# Kuala Lumpur -> GPE
# 10th November 2025 -> DATE
# UN -> ORG
#
# Text: Apple Inc. announced the release of the new iPhone 15, priced at $999, at their headquarters in Cupertino.
# Apple Inc. -> ORG
# 15 -> CARDINAL
# 999 -> MONEY
# Cupertino -> GPE
#
# Text: The Eiffel Tower is one of the most famous landmarks in Paris.
# The Eiffel Tower -> LOC
# one -> CARDINAL
# Paris -> GPE
#
# Text: Python and Java are popular programming languages used in AI and data science projects.
# Java -> PERSON
# AI -> GPE
#
# Text: The company achieved a 25% increase in revenue this quarter.
# 25% -> PERCENT
# this quarter -> DATE
#
# Text: The World Cup 2026 will be held in multiple cities across the USA, Canada, and Mexico.
# The World Cup 2026 -> EVENT
# USA -> GPE
# Canada -> GPE
# Mexico -> GPE
#
# Text: The Malaysian Parliament passed the new Data Protection Act yesterday.
# ...
