# %% [markdown]
# # matplotlib.pyplot.subplot()
# ### subplots(): provides a way to plot multiple plots on a single figure
# ### Given number of rows and columns. It returns a tuple (fig, ax) giving a single figure fig with an array of axes ax

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1,ax2), (ax3,ax4))=plt.subplots (nrows=2,ncols=2, figsize=(10,5))

# %%
sales_data={'Electronics':45000,'Clothing':30000,'Grocery':25000,'Mobile':20000}
category=list(sales_data.keys())
actual_sale=list(sales_data.values())
fig, ((ax1,ax2), (ax3,ax4))=plt.subplots (nrows=2,ncols=2, figsize=(10,5))
x=np.random.random(10)
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(category,actual_sale)
ax4.hist(np.random.randn(1000))
# Out:
# (array([  3.,  10.,  59., 153., 220., 237., 191.,  89.,  25.,  13.]),
#  array([-3.24639868, -2.61965342, -1.99290816, -1.3661629 , -0.73941765,
#         -0.11267239,  0.51407287,  1.14081813,  1.76756339,  2.39430865,
#          3.0210539 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Subplots Using Indexes

# %%
our_lines=np.linspace(0,10,100)
product_prices={'Hair Oil':20,'Face Wash':30,'Lip Balm':10,'Face Cream':15}
our_numbers=np.random.random(10)
our_dots=np.random.randn(1000)

fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax[0,0].plot(our_lines,our_lines/2)
ax[0,1].bar(list(product_prices.keys()), list(product_prices.values()),color=['blue','green','red','orange'])
ax[1,0].scatter(np.random.random(10),np.random.random(10))
ax[1,1].hist(our_dots,color='red')

plt.tight_layout()

# %% [markdown]
# ### Customize any graph e.g. ax[0,0]

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax[0,0].plot(our_lines,our_lines/2)
ax[0,0].set_title('Line Example')            # Customize any graph e.g. ax[0,0]
ax[0,0].grid(True, linestyle='--', alpha=0.5)

ax[0,1].bar(list(product_prices.keys()), list(product_prices.values()),color=['blue','green','red','orange'])
ax[1,0].scatter(np.random.random(10),np.random.random(10))
ax[1,1].hist(our_dots,color='red')

plt.tight_layout()

# %% [markdown]
# ### Further Customize Graphs

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,5))

# Line Plot [0,0]
ax[0,0].plot(our_lines, our_lines/2)
ax[0,0].set_title('Line Plot Example')
ax[0,0].set_xlabel('X Axis')
ax[0,0].set_ylabel('Y Axis')
ax[0,0].grid(True, linestyle='-', alpha=0.7, color='lightblue', axis='y')

# Bar Plot [0,1]
ax[0,1].bar(list(product_prices.keys()), list(product_prices.values()), color=['blue', 'green', 'red', 'orange'])
ax[0,1].set_title('Product Sales Information')
ax[0,1].set_xlabel('Products Name')
ax[0,1].set_ylabel('Product Sale')
ax[0,1].grid(True, linestyle='--', alpha=0.7, color='lightgreen', axis='y')

# Scatter Plot [1,0]
ax[1,0].scatter(np.random.randn(100), np.random.randn(100), color='orange')
ax[1,0].set_title('Our Scatter Plot')
ax[1,0].set_xlabel('X Values')
ax[1,0].set_ylabel('Y Values')
ax[1,0].grid(True, linestyle=':', alpha=0.7, color='lightblue')

# Histogram [1,1]
ax[1,1].hist(our_dots, color='red')
ax[1,1].set_title('Histogram Example')
ax[1,1].set_xlabel('Value Range')
ax[1,1].set_ylabel('Frequency')
ax[1,1].grid(True, linestyle='--', alpha=0.7, color='orange')

# Figure title
fig.suptitle('Matplotlib Subplots Example: 2 Rows × 2 Columns', fontsize=14)

plt.tight_layout()
plt.show()
plt.savefig('subplotex.jpeg',dpi=300,bbox_inches='tight')

# %%
fig,ax=plt.subplots(nrows=3,ncols=2,figsize=(10,5))
ax[2,1].plot(our_lines,our_lines/2)
