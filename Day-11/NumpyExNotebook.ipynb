# %% [markdown]
# # Numpy Introduction and Usage
# ## We will use numpy in this Jupyter notebook
# ## One-Dimensional Array (1-D)

# %%
import numpy as np

# %%
array1=np.array([10,20,30,40,50,80])

# %%
print(array1)
# Out:
# [10 20 30 40 50 80]

# %% [markdown]
# # Two-Dimensional Array (2-D)

# %%
array_two=np.array([[10,20,30],[40,50,70]])

# %%
print(array_two)
# Out:
# [[10 20 30]
#  [40 50 70]]

# %% [markdown]
# # Three Dimensional Array ( 3-D Array)

# %%
array_three=np.array([[[10,20,30],[40,50,70]],[[10,20,30],[40,50,70]]])

# %%
print(array_three)
# Out:
# [[[10 20 30]
#   [40 50 70]]
#
#  [[10 20 30]
#   [40 50 70]]]

# %% [markdown]
# # Find out Dimension of NumPy array

# %%
print('First Array Dimension: \t', array1.ndim)
# Out:
# First Array Dimension: 	 1

# %%
print('Second Array Dimension: \t', array_two.ndim)
# Out:
# Second Array Dimension: 	 2

# %%
print('Third Array Dimension: \t', array_three.ndim)
# Out:
# Third Array Dimension: 	 3

# %% [markdown]
# # Write an array of 5 student's using Numpy
#     ## Marks are: 80,70,75,99,89

# %%
array_marks=np.array([80,70,75,99,89,90])
print('Array of Marks:')
print(array_marks)
# Out:
# Array of Marks:
# [80 70 75 99 89 90]

# %% [markdown]
# # Write an array: to take the Marks of 5 students in 3 subjects using Numpy

# %% [markdown]
# ## Math, English, Chemistry

# %% [markdown]
# ## [[50,45,49],[40,42,45],[35,40,46],[39,40,45],[48,40,40]]

# %%
marks_subject=np.array([[50,45,49],[40,42,45],[35,40,46],[39,40,45],[48,40,40]])
print('2 D Array Example')
print(marks_subject)
# Out:
# 2 D Array Example
# [[50 45 49]
#  [40 42 45]
#  [35 40 46]
#  [39 40 45]
#  [48 40 40]]

# %% [markdown]
# # Write an array: to take Marks of 4 students in 3 subjects for two semester using Numpy
#      ## Students Name are: 'Amit','Sha','Xi','Arif'
#      ## Math, English, Chemistry
#      ## Two Semester : Sem1 , Sem2
#      ## 4*3*2 (The Array)
#      ## ([[[85, 88],[78, 82],[90, 95]] , [[76, 70],[40, 45],[90, 90]] ,[[80, 86],[78, 82],[90, 95]],[[85, 88],[78, 82],[70, 90]]])

# %%
marks_subject_sem=np.array([
    [[85, 88],[78, 82],[90, 95]], 
    [[76, 70],[40, 45],[90, 90]],
    [[80, 86],[78, 82],[90, 95]],
    [[85, 88],[78, 82],[70, 90]]
])

# %%
print (marks_subject_sem)
# Out:
# [[[85 88]
#   [78 82]
#   [90 95]]
#
#  [[76 70]
#   [40 45]
#   [90 90]]
#
#  [[80 86]
#   [78 82]
#   [90 95]]
#
#  [[85 88]
#   [78 82]
#   [70 90]]]

# %% [markdown]
# # Write an array: to take wheather of 2 cities in 3 days for three times in a day for morning, noon ,evening
#     ## Cities Name are: Kuala Lumpur, Delhi
#     ## Saturday, Sunday, Monday
#     ## Three Time Slot : Morning, Noon, Evening
#     ## Kuala Lumpur :[[25,30,28],[24,28,25],[30,32,30]]
#     ## Delhi:[[30,35,30],[32,34,30],[28,31,30]]
#     ## [[[25,30,28],[24,28,25],[30,32,30]],[[30,35,30],[32,34,30],[28,31,30]]]

# %% [markdown]
# ### Create one 3D Array for this using NumPy and print it

# %%
wheather_array=np.array([[[25,30,28],[24,28,25],[30,32,30]],[[30,35,30],[32,34,30],[28,31,30]]])

# %%
print(wheather_array)
# Out:
# [[[25 30 28]
#   [24 28 25]
#   [30 32 30]]
#
#  [[30 35 30]
#   [32 34 30]
#   [28 31 30]]]

# %% [markdown]
# # Basic Information
#     ## shape: rows and columns
#     ## Size: number of elements
#     ## Dimension: return dimension 1, 2, 3....
#     ## Data Type: return stored data values type

# %%
print(array1)
# Out:
# [10 20 30 40 50 80]

# %%
print("Shape of array1 : ",array1.shape)
# Out:
# Shape of array1 :  (6,)

# %%
print("Size of array1 : ",array1.size)
# Out:
# Size of array1 :  6

# %%
print ('Dimension: ',array1.ndim)
# Out:
# Dimension:  1

# %%
print ('Data Type: ',array1.dtype)
# Out:
# Data Type:  int64

# %%
students=np.array(['Ali Munaf Bin Kabir','Shi','Xi','Meena','Ziva'])

# %%
print(students)
# Out:
# ['Ali Munaf Bin Kabir' 'Shi' 'Xi' 'Meena' 'Ziva']

# %%
print("Shape of Array : ",students.shape)
# Out:
# Shape of Array :  (5,)

# %%
print('Number of students',students.size)
# Out:
# Number of students 5

# %%
print('Data Type: ',students.dtype)
# Out:
# Data Type:  <U19

# %% [markdown]
# # Mathematical Operation

# %%
print(array1)
# Out:
# [10 20 30 40 50 80]

# %%
total=np.sum(array1)

# %%
print(total)
# Out:
# 230

# %%
print('Mean: ',np.mean(array1))
# Out:
# Mean:  38.333333333333336

# %%
print('Min: ',np.min(array1))
# Out:
# Min:  10

# %%
print('Max: ',np.max(array1))
# Out:
# Max:  80

# %%
print('The Min is at Index: ',np.argmin(array1))
# Out:
# The Min is at Index:  0

# %%
print('The Max is at Index: ',np.argmax(array1))
# Out:
# The Max is at Index:  5

# %%
our_arr=np.array([100,200,300,7000,400,500,300,1900,600])

# %%
print(our_arr)
# Out:
# [ 100  200  300 7000  400  500  300 1900  600]

# %% [markdown]
# # Searching and Sorting Example in 1D Array

# %%
sorted_arr=np.sort(our_arr)
print('*** Sorted Array ')
print(sorted_arr)
# Out:
# *** Sorted Array
# [ 100  200  300  300  400  500  600 1900 7000]

# %%
print('Is there any item greater than 500 ?: ',np.any(sorted_arr>500))
# Out:
# Is there any item greater than 500 ?:  True

# %%
print('All greater than 500 ?: ',np.all(sorted_arr>500))
# Out:
# All greater than 500 ?:  False

# %%
print('All greater than 99 ?: ',np.all(sorted_arr>99))
# Out:
# All greater than 99 ?:  True

# %%
print('Where values >500',np.where(sorted_arr>500))
# Out:
# Where values >500 (array([6, 7, 8]),)

# %%
print('All Number greater than 500')
for num in np.where(sorted_arr>500):
    print (num)
# Out:
# All Number greater than 500
# [6 7 8]

# %%
print(our_arr)
# Out:
# [ 100  200  300 7000  400  500  300 1900  600]

# %%
print(np.min(our_arr))
# Out:
# 100

# %%
print('Index of Min: ',np.argmin(our_arr))
# Out:
# Index of Min:  0

# %%
print('Index of Max',np.argmax(sorted_arr))
# Out:
# Index of Max 8

# %%
print('All Number greater than 500')
for num in sorted_arr>500:
    print (num)
# Out:
# All Number greater than 500
# False
# False
# False
# False
# False
# False
# True
# True
# True

# %%
selected_values=sorted_arr[sorted_arr>500]

# %%
print(selected_values)
# Out:
# [ 600 1900 7000]

# %%
for num in selected_values:
    print (num)
# Out:
# 600
# 1900
# 7000

# %%
for num in sorted_arr[sorted_arr>500]:
    print(num)
# Out:
# 600
# 1900
# 7000

# %%
print(' ',sorted_arr[sorted_arr>500])
# Out:
#   [ 600 1900 7000]

# %% [markdown]
# # Slicing 1 D Array
#     1. To take elements from an index (included) to an index (not included)
#     2. e.g. [start:end]

# %%
print(sorted_arr)
# Out:
# [ 100  200  300  300  400  500  600 1900 7000]

# %%
slice_sorted_arr=sorted_arr[1:3]
print(slice_sorted_arr)
# Out:
# [200 300]

# %% [markdown]
# # Starting from an index and going till the last

# %%
sorted_arr
# Out:
# array([ 100,  200,  300,  300,  400,  500,  600, 1900, 7000])

# %% [markdown]
# ### print(sorted_arr[3:])

# %%
print("This will start from index 3, and take everything after it:", sorted_arr[3:])
# Out:
# This will start from index 3, and take everything after it: [ 300  400  500  600 1900 7000]

# %% [markdown]
# ### print(sorted_arr[:4])

# %%
print('This will take everything from the beginning up to index 4 (not including 4)',sorted_arr[:4])
# Out:
# This will take everything from the beginning up to index 4 (not including 4) [100 200 300 300]

# %% [markdown]
# ### print(sorted_arr[:5])

# %%
print('This will take everything from the beginning up to index 5 (not including 5)',sorted_arr[:5])
# Out:
# This will take everything from the beginning up to index 5 (not including 5) [100 200 300 300 400]

# %% [markdown]
# # Step
#     ## [start:end:step]
#     ## step: every step element

# %%
our_slice=sorted_arr[1:6:2]
print (our_slice)
# Out:
# [200 300 500]

# %%
print('Original Array')
print(sorted_arr)
print('Every Third Element')
every_third_element=sorted_arr[::3]
print(every_third_element)
# Out:
# Original Array
# [ 100  200  300  300  400  500  600 1900 7000]
# Every Third Element
# [100 300 600]

# %% [markdown]
# # Slice Reverse

# %%
print('Original Array')
print(sorted_arr)
print('Reverse Array: ')
print(sorted_arr[::-1])
# Out:
# Original Array
# [ 100  200  300  300  400  500  600 1900 7000]
# Reverse Array:
# [7000 1900  600  500  400  300  300  200  100]

# %%
print('Last five elements')
print(sorted_arr[::-5])
# Out:
# Last five elements
# [7000  300]

# %%
print('Slicing is Done')
# Out:
# Slicing is Done

# %%
print('In reverse, will step (leave) the second number')
print(sorted_arr[::-2])
# Out:
# In reverse, will step (leave) the second number
# [7000  600  400  300  100]

# %%
import os, time
path = "NumpyExNotebook.ipynb"
print("Last modified:", time.ctime(os.path.getmtime(path)))
# Out:
# Last modified: Sun Oct 26 17:12:30 2025
